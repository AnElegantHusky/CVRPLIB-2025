# %%
# %load_ext autoreload
# %autoreload 2

import os
import pandas as pd
import matplotlib.pyplot as plt
from plot_utils import plot_search_curves, plot_best_fitness, plot_gap_scatter, plot_gap_scatter_from_sol, get_fitness_table
# %matplotlib notebook

# %%
from plot_utils import plot_best_fitness

algorithm_names = [
    'AILSII_continue_1',
    'AILS2_EoH_Acc_large_continue.jar',
    'AILS2_EoH_Omega2_continue.jar',
    # 'AILSII_continue_Mahdi',
    # 'Mahdi_baseline'
    # 'AILSII_continue_2',
    
    # 'AILSII_continue_eoh_1',
    # 'AILSII_continue_eoh_2'
    # 'EoH_Acc',
    # 'EoH_Omega'
    
]

# instance_dir = '../XLTEST'
instance_dir = '../XLTEST'

instance_names = [i.split('.')[0] for i in os.listdir(instance_dir) if i.endswith('.vrp')]
# instance_names = [instance_names[i] for i in [70, 80, 90, 97]]

# %%
import re
def extract_n_value(filename):
    # 正则表达式解释：
    # n      : 匹配字符 'n'
    # (\d+)  : 捕获组，匹配一个或多个数字
    match = re.search(r'n(\d+)', filename)
    if match:
        return int(match.group(1)) # 返回整数类型以便正确排序
    return 0 # 如果没找到，返回0排在最后

instance_names = sorted(instance_names, key=extract_n_value, reverse=False)

# %%
instance_names
# Out:
# ['XLTEST-n1048-k139',
#  'XLTEST-n1094-k9',
#  'XLTEST-n1141-k75',
#  'XLTEST-n1188-k72',
#  'XLTEST-n1234-k252',
#  'XLTEST-n1281-k42',
#  'XLTEST-n1328-k115',
#  'XLTEST-n1374-k71',
#  'XLTEST-n1421-k12',
#  'XLTEST-n1468-k47',
#  'XLTEST-n1514-k125',
#  'XLTEST-n1561-k156',
#  'XLTEST-n1608-k488',
#  'XLTEST-n1654-k322',
#  'XLTEST-n1701-k10',
#  'XLTEST-n1748-k293',
#  'XLTEST-n1794-k405',
#  'XLTEST-n1841-k37',
#  'XLTEST-n1888-k206',
#  'XLTEST-n1934-k107',
#  'XLTEST-n1981-k146',
#  'XLTEST-n2028-k406',
#  'XLTEST-n2074-k225',
#  'XLTEST-n2121-k107',
#  'XLTEST-n2168-k625',
#  'XLTEST-n2214-k61',
#  'XLTEST-n2261-k168',
#  'XLTEST-n2307-k13',
#  'XLTEST-n2354-k217',
#  'XLTEST-n2401-k16',
#  'XLTEST-n2447-k199',
#  'XLTEST-n2494-k624',
#  'XLTEST-n2541-k92',
#  'XLTEST-n2587-k114',
#  'XLTEST-n2634-k380',
#  'XLTEST-n2681-k15',
#  'XLTEST-n2727-k175',
#  'XLTEST-n2774-k349',
#  'XLTEST-n2821-k336',
#  'XLTEST-n2867-k169',
#  'XLTEST-n2914-k852',
#  'XLTEST-n2961-k73',
#  'XLTEST-n3007-k152',
#  'XLTEST-n3054-k306',
#  'XLTEST-n3101-k685',
#  'XLTEST-n3147-k215',
#  'XLTEST-n3194-k93',
#  'XLTEST-n3241-k628',
#  'XLTEST-n3287-k35',
#  'XLTEST-n3334-k1011',
#  'XLTEST-n3408-k627',
#  'XLTEST-n3484-k291',
#  'XLTEST-n3561-k54',
#  'XLTEST-n3640-k144',
#  'XLTEST-n3721-k197',
#  'XLTEST-n3804-k254',
#  'XLTEST-n3888-k548',
#  'XLTEST-n3975-k489',
#  'XLTEST-n4063-k944',
#  'XLTEST-n4153-k218',
#  'XLTEST-n4245-k164',
#  'XLTEST-n4340-k33',
#  'XLTEST-n4436-k335',
#  'XLTEST-n4535-k1092',
#  'XLTEST-n4635-k313',
#  'XLTEST-n4738-k456',
#  'XLTEST-n4844-k45',
#  'XLTEST-n4951-k225',
#  'XLTEST-n5061-k951',
#  'XLTEST-n5174-k170',
#  'XLTEST-n5288-k482',
#  'XLTEST-n5406-k29',
#  'XLTEST-n5526-k321',
#  'XLTEST-n5649-k365',
#  'XLTEST-n5774-k885',
#  'XLTEST-n5902-k126',
#  'XLTEST-n6034-k1234',
#  'XLTEST-n6168-k554',
#  'XLTEST-n6305-k58',
#  'XLTEST-n6445-k189',
#  'XLTEST-n6588-k267',
#  'XLTEST-n6734-k1123',
#  'XLTEST-n6884-k434',
#  'XLTEST-n7037-k2302',
#  'XLTEST-n7193-k157',
#  'XLTEST-n7353-k77',
#  'XLTEST-n7516-k1223',
#  'XLTEST-n7683-k1624',
#  'XLTEST-n7854-k395',
#  'XLTEST-n8028-k986',
#  'XLTEST-n8207-k649',
#  'XLTEST-n8389-k1106',
#  'XLTEST-n8575-k343',
#  'XLTEST-n8766-k154',
#  'XLTEST-n8960-k2144',
#  'XLTEST-n9160-k364',
#  'XLTEST-n9363-k744',
#  'XLTEST-n9571-k980',
#  'XLTEST-n9784-k890',
#  'XLTEST-n10001-k806']

# %%
cur_instance_names = instance_names[50:]

result_dir = '../remote_results/test-continue-XLTEST'
plot_dir = '../figures/continue-XLTEST'

df = get_fitness_table(cur_instance_names, algorithm_names, base_dir=result_dir)
df
# Out:
# --- 开始生成 Fitness 表格 (基于 .sol 文件) ---
#
# --- Fitness 表格预览 ---
#                    AILSII_continue_1  AILS2_EoH_Acc_large_continue.jar  \
# Instance
# XLTEST-n3408-k627           526011.0                          525974.0
# XLTEST-n3484-k291           566243.0                          566255.0
# XLTEST-n3561-k54             63452.0                           63455.0
# XLTEST-n3640-k144           138232.0                          138229.0
# XLTEST-n3721-k197           264532.0                          264569.0
#
#                    AILS2_EoH_Omega2_continue.jar
# Instance
# XLTEST-n3408-k627                       526020.0
# XLTEST-n3484-k291                       566032.0
# XLTEST-n3561-k54                         63447.0
# XLTEST-n3640-k144                       138226.0
# XLTEST-n3721-k197                       264565.0
#                     AILSII_continue_1  AILS2_EoH_Acc_large_continue.jar  \
# Instance
# XLTEST-n3408-k627            526011.0                          525974.0
# XLTEST-n3484-k291            566243.0                          566255.0
# XLTEST-n3561-k54              63452.0                           63455.0
# XLTEST-n3640-k144            138232.0                          138229.0
# XLTEST-n3721-k197            264532.0                          264569.0
# XLTEST-n3804-k254            464930.0                          464955.0
# XLTEST-n3888-k548            453864.0                          453953.0
# XLTEST-n3975-k489            420024.0                          420050.0
# XLTEST-n4063-k944            932127.0                          932402.0
# XLTEST-n4153-k218            358051.0                          358164.0
# XLTEST-n4245-k164            192302.0                          192310.0
# XLTEST-n4340-k33              70104.0                           70102.0
# XLTEST-n4436-k335            280430.0                          280448.0
# XLTEST-n4535-k1092          1625431.0                         1626400.0
# XLTEST-n4635-k313            256790.0                          256793.0
# XLTEST-n4738-k456            381988.0                          381976.0
# XLTEST-n4844-k45              66733.0                           66725.0
# XLTEST-n4951-k225            383905.0                          383912.0
# XLTEST-n5061-k951            666237.0                          665902.0
# XLTEST-n5174-k170            306239.0                          306278.0
# XLTEST-n5288-k482            426267.0                          426325.0
# XLTEST-n5406-k29              44258.0                           44259.0
# XLTEST-n5526-k321            356719.0                          356914.0
# XLTEST-n5649-k365            589338.0                          589418.0
# XLTEST-n5774-k885            672424.0                          672420.0
# XLTEST-n5902-k126            131231.0                          131265.0
# XLTEST-n6034-k1234           990913.0                          991035.0
# XLTEST-n6168-k554           1229587.0                         1229749.0
# XLTEST-n6305-k58             122975.0                          122997.0
# XLTEST-n6445-k189             83957.0                           83959.0
# XLTEST-n6588-k267            320109.0                          320122.0
# XLTEST-n6734-k1123           895169.0                          895167.0
# XLTEST-n6884-k434            491649.0                          491706.0
# XLTEST-n7037-k2302          3427706.0                         3428441.0
# XLTEST-n7193-k157            170792.0                          170812.0
# XLTEST-n7353-k77              79532.0                           79551.0
# XLTEST-n7516-k1223          1909828.0                         1910214.0
# XLTEST-n7683-k1624          1680559.0                         1680624.0
# XLTEST-n7854-k395            633783.0                          633927.0
# XLTEST-n8028-k986            806699.0                          806826.0
# XLTEST-n8207-k649            845701.0                          845686.0
# XLTEST-n8389-k1106          1737078.0                         1737868.0
# XLTEST-n8575-k343            231345.0                          231381.0
# XLTEST-n8766-k154            251507.0                          251515.0
# XLTEST-n8960-k2144          1968886.0                         1969089.0
# XLTEST-n9160-k364            454840.0                          454902.0
# XLTEST-n9363-k744            871970.0                          872029.0
# XLTEST-n9571-k980           1359894.0                         1360091.0
# XLTEST-n9784-k890            724128.0                          724133.0
# XLTEST-n10001-k806           656978.0                               NaN
#
#                     AILS2_EoH_Omega2_continue.jar
# Instance
# XLTEST-n3408-k627                        526020.0
# XLTEST-n3484-k291                        566032.0
# XLTEST-n3561-k54                          63447.0
# XLTEST-n3640-k144                        138226.0
# XLTEST-n3721-k197                        264565.0
# XLTEST-n3804-k254                        464935.0
# XLTEST-n3888-k548                        453878.0
# XLTEST-n3975-k489                        420046.0
# XLTEST-n4063-k944                        932227.0
# XLTEST-n4153-k218                        358091.0
# XLTEST-n4245-k164                        192358.0
# XLTEST-n4340-k33                          70112.0
# XLTEST-n4436-k335                        280427.0
# XLTEST-n4535-k1092                      1625802.0
# XLTEST-n4635-k313                        256750.0
# XLTEST-n4738-k456                        381971.0
# XLTEST-n4844-k45                          66721.0
# XLTEST-n4951-k225                        383902.0
# XLTEST-n5061-k951                        666069.0
# XLTEST-n5174-k170                        306268.0
# XLTEST-n5288-k482                        426312.0
# XLTEST-n5406-k29                          44268.0
# XLTEST-n5526-k321                        356780.0
# XLTEST-n5649-k365                        589500.0
# XLTEST-n5774-k885                        672586.0
# XLTEST-n5902-k126                        131264.0
# XLTEST-n6034-k1234                       990986.0
# XLTEST-n6168-k554                       1229611.0
# XLTEST-n6305-k58                         122998.0
# XLTEST-n6445-k189                         83954.0
# XLTEST-n6588-k267                        320112.0
# XLTEST-n6734-k1123                       895167.0
# XLTEST-n6884-k434                        491715.0
# XLTEST-n7037-k2302                      3429272.0
# XLTEST-n7193-k157                        170803.0
# XLTEST-n7353-k77                          79543.0
# XLTEST-n7516-k1223                      1909956.0
# XLTEST-n7683-k1624                      1680729.0
# XLTEST-n7854-k395                        633803.0
# XLTEST-n8028-k986                        806788.0
# XLTEST-n8207-k649                        845663.0
# XLTEST-n8389-k1106                      1737486.0
# XLTEST-n8575-k343                        231379.0
# XLTEST-n8766-k154                        251533.0
# XLTEST-n8960-k2144                      1969606.0
# XLTEST-n9160-k364                        454887.0
# XLTEST-n9363-k744                        872006.0
# XLTEST-n9571-k980                       1360116.0
# XLTEST-n9784-k890                        724141.0
# XLTEST-n10001-k806                            NaN

# %%
# base_col = df.columns[0]  # 第一列 (作为基准)
# target_col = df.columns[1] # 第二列 (用于对比)
# 
# # 2. 定义新列的名称 (例如: Gap_MethodB_vs_MethodA)
# gap_col_name = f'Gap_{target_col}_vs_{base_col}'
# 
# # 3. 计算 Gap: ((Target - Base) / Base) * 100
# df[gap_col_name] = ((df[target_col] - df[base_col]) / df[base_col]) * 100
# 
# df

# %%
for instance in cur_instance_names:
    plot_best_fitness(instance, algorithm_names, base_dir=result_dir, output_dir=plot_dir)
# Out:
# <div id='ae8e8565-2d53-4f80-bf49-fb2d4c0708dc'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3408-k627 ---
# AILSII_continue_1: 124 entries | best fitness: 526011.0
# AILS2_EoH_Acc_large_continue.jar: 163 entries | best fitness: 525974.0
# AILS2_EoH_Omega2_continue.jar: 131 entries | best fitness: 526020.0
# --- 绘图完成: XLTEST-n3408-k627, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3408-k627.png ---
# <div id='f40fdee4-699e-48c7-a290-db3334d36611'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3484-k291 ---
# AILSII_continue_1: 154 entries | best fitness: 566243.0
# AILS2_EoH_Acc_large_continue.jar: 76 entries | best fitness: 566255.0
# AILS2_EoH_Omega2_continue.jar: 193 entries | best fitness: 566032.0
# --- 绘图完成: XLTEST-n3484-k291, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3484-k291.png ---
# <div id='ec67f25c-6667-4033-b98c-83fe71509de4'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3561-k54 ---
# AILSII_continue_1: 23 entries | best fitness: 63452.0
# AILS2_EoH_Acc_large_continue.jar: 23 entries | best fitness: 63455.0
# AILS2_EoH_Omega2_continue.jar: 27 entries | best fitness: 63447.0
# --- 绘图完成: XLTEST-n3561-k54, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3561-k54.png ---
# <div id='c01b6010-582e-4c73-a24d-1879d5a7e3c8'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3640-k144 ---
# AILSII_continue_1: 25 entries | best fitness: 138232.0
# AILS2_EoH_Acc_large_continue.jar: 20 entries | best fitness: 138229.0
# AILS2_EoH_Omega2_continue.jar: 26 entries | best fitness: 138226.0
# --- 绘图完成: XLTEST-n3640-k144, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3640-k144.png ---
# <div id='c1bc592d-7ff5-4786-80fa-fdbc99750071'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3721-k197 ---
# AILSII_continue_1: 145 entries | best fitness: 264532.0
# AILS2_EoH_Acc_large_continue.jar: 114 entries | best fitness: 264569.0
# AILS2_EoH_Omega2_continue.jar: 122 entries | best fitness: 264565.0
# --- 绘图完成: XLTEST-n3721-k197, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3721-k197.png ---
# <div id='64864249-f60b-4b71-9fd1-56eca346efbe'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3804-k254 ---
# AILSII_continue_1: 100 entries | best fitness: 464930.0
# AILS2_EoH_Acc_large_continue.jar: 71 entries | best fitness: 464955.0
# AILS2_EoH_Omega2_continue.jar: 100 entries | best fitness: 464935.0
# --- 绘图完成: XLTEST-n3804-k254, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3804-k254.png ---
# <div id='e0ebb817-1b92-4702-a8ca-cea70df98528'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3888-k548 ---
# AILSII_continue_1: 80 entries | best fitness: 453864.0
# AILS2_EoH_Acc_large_continue.jar: 5 entries | best fitness: 453953.0
# AILS2_EoH_Omega2_continue.jar: 57 entries | best fitness: 453878.0
# --- 绘图完成: XLTEST-n3888-k548, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3888-k548.png ---
# <div id='80d4f7e8-26bc-4350-93bb-7b662248be94'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3975-k489 ---
# AILSII_continue_1: 164 entries | best fitness: 420024.0
# AILS2_EoH_Acc_large_continue.jar: 123 entries | best fitness: 420050.0
# AILS2_EoH_Omega2_continue.jar: 141 entries | best fitness: 420046.0
# --- 绘图完成: XLTEST-n3975-k489, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n3975-k489.png ---
# <div id='2a4c23f7-667b-4738-a21d-e100bc054c47'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4063-k944 ---
# AILSII_continue_1: 514 entries | best fitness: 932127.0
# AILS2_EoH_Acc_large_continue.jar: 208 entries | best fitness: 932402.0
# AILS2_EoH_Omega2_continue.jar: 415 entries | best fitness: 932227.0
# --- 绘图完成: XLTEST-n4063-k944, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4063-k944.png ---
# <div id='a7d20165-f20e-4605-90f7-5c1a38083779'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4153-k218 ---
# AILSII_continue_1: 325 entries | best fitness: 358051.0
# AILS2_EoH_Acc_large_continue.jar: 205 entries | best fitness: 358164.0
# AILS2_EoH_Omega2_continue.jar: 311 entries | best fitness: 358091.0
# --- 绘图完成: XLTEST-n4153-k218, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4153-k218.png ---
# <div id='82c97b46-6f63-44c6-b4c9-89c189c9485a'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4245-k164 ---
# AILSII_continue_1: 50 entries | best fitness: 192302.0
# AILS2_EoH_Acc_large_continue.jar: 33 entries | best fitness: 192310.0
# 警告: 文件 ../remote_results/test-continue-XLTEST/AILS2_EoH_Omega2_continue.jar/XLTEST-n4245-k164_1.csv 为空, 跳过。
# --- 绘图完成: XLTEST-n4245-k164, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4245-k164.png ---
# <div id='df91d2d0-d3cd-4e45-bd8a-a1d907cabc1a'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4340-k33 ---
# AILSII_continue_1: 10 entries | best fitness: 70104.0
# AILS2_EoH_Acc_large_continue.jar: 12 entries | best fitness: 70102.0
# AILS2_EoH_Omega2_continue.jar: 2 entries | best fitness: 70112.0
# --- 绘图完成: XLTEST-n4340-k33, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4340-k33.png ---
# <div id='5098c0bb-0a8f-40e6-a243-3ab1f28db35c'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4436-k335 ---
# AILSII_continue_1: 131 entries | best fitness: 280430.0
# AILS2_EoH_Acc_large_continue.jar: 100 entries | best fitness: 280448.0
# AILS2_EoH_Omega2_continue.jar: 123 entries | best fitness: 280427.0
# --- 绘图完成: XLTEST-n4436-k335, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4436-k335.png ---
# <div id='9dc6d0ba-f198-4b7a-be86-24dc5a573214'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4535-k1092 ---
# AILSII_continue_1: 728 entries | best fitness: 1625431.0
# AILS2_EoH_Acc_large_continue.jar: 213 entries | best fitness: 1626400.0
# AILS2_EoH_Omega2_continue.jar: 532 entries | best fitness: 1625802.0
# --- 绘图完成: XLTEST-n4535-k1092, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4535-k1092.png ---
# <div id='a72c3122-01f0-41fe-bcdb-9623fc9e3f1f'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4635-k313 ---
# AILSII_continue_1: 115 entries | best fitness: 256790.0
# AILS2_EoH_Acc_large_continue.jar: 94 entries | best fitness: 256793.0
# AILS2_EoH_Omega2_continue.jar: 145 entries | best fitness: 256750.0
# --- 绘图完成: XLTEST-n4635-k313, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4635-k313.png ---
# <div id='999b87ef-e64b-49c7-ac6e-6fab5b06d9f0'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4738-k456 ---
# AILSII_continue_1: 145 entries | best fitness: 381988.0
# AILS2_EoH_Acc_large_continue.jar: 71 entries | best fitness: 381976.0
# AILS2_EoH_Omega2_continue.jar: 163 entries | best fitness: 381971.0
# --- 绘图完成: XLTEST-n4738-k456, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4738-k456.png ---
# <div id='9dbefea1-db9f-4c5c-91d2-287d84717419'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4844-k45 ---
# AILSII_continue_1: 3 entries | best fitness: 66733.0
# AILS2_EoH_Acc_large_continue.jar: 11 entries | best fitness: 66725.0
# AILS2_EoH_Omega2_continue.jar: 13 entries | best fitness: 66721.0
# --- 绘图完成: XLTEST-n4844-k45, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4844-k45.png ---
# <div id='3bc70011-7078-4111-90b8-5c84a0c16907'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4951-k225 ---
# AILSII_continue_1: 46 entries | best fitness: 383905.0
# AILS2_EoH_Acc_large_continue.jar: 46 entries | best fitness: 383912.0
# AILS2_EoH_Omega2_continue.jar: 48 entries | best fitness: 383902.0
# --- 绘图完成: XLTEST-n4951-k225, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n4951-k225.png ---
# <div id='4554fb9f-094c-4731-ba99-32302513ef86'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5061-k951 ---
# AILSII_continue_1: 58 entries | best fitness: 666237.0
# AILS2_EoH_Acc_large_continue.jar: 326 entries | best fitness: 665902.0
# AILS2_EoH_Omega2_continue.jar: 169 entries | best fitness: 666069.0
# --- 绘图完成: XLTEST-n5061-k951, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5061-k951.png ---
# <div id='b4ada28e-b725-4a3b-82f0-dd07bf728577'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5174-k170 ---
# AILSII_continue_1: 121 entries | best fitness: 306239.0
# AILS2_EoH_Acc_large_continue.jar: 91 entries | best fitness: 306278.0
# AILS2_EoH_Omega2_continue.jar: 110 entries | best fitness: 306268.0
# --- 绘图完成: XLTEST-n5174-k170, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5174-k170.png ---
# /home/chenxin/CVRPLIB-2025/plot/plot_utils.py:123: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(12, 7))
# <div id='5179deed-d6c7-4914-bee2-7537a3ccf8aa'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5288-k482 ---
# AILSII_continue_1: 177 entries | best fitness: 426267.0
# AILS2_EoH_Acc_large_continue.jar: 133 entries | best fitness: 426325.0
# AILS2_EoH_Omega2_continue.jar: 138 entries | best fitness: 426312.0
# --- 绘图完成: XLTEST-n5288-k482, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5288-k482.png ---
# <div id='a85aab8a-191b-4a71-9844-719fcef33cd4'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5406-k29 ---
# AILSII_continue_1: 16 entries | best fitness: 44258.0
# AILS2_EoH_Acc_large_continue.jar: 16 entries | best fitness: 44259.0
# AILS2_EoH_Omega2_continue.jar: 6 entries | best fitness: 44268.0
# --- 绘图完成: XLTEST-n5406-k29, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5406-k29.png ---
# <div id='d764711e-7cd0-467b-b2b4-60a5fe0c81fd'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5526-k321 ---
# AILSII_continue_1: 444 entries | best fitness: 356719.0
# AILS2_EoH_Acc_large_continue.jar: 286 entries | best fitness: 356914.0
# AILS2_EoH_Omega2_continue.jar: 383 entries | best fitness: 356780.0
# --- 绘图完成: XLTEST-n5526-k321, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5526-k321.png ---
# <div id='d0dc129c-7504-4754-8c86-d99a9247799e'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5649-k365 ---
# AILSII_continue_1: 410 entries | best fitness: 589338.0
# AILS2_EoH_Acc_large_continue.jar: 216 entries | best fitness: 589418.0
# AILS2_EoH_Omega2_continue.jar: 363 entries | best fitness: 589500.0
# --- 绘图完成: XLTEST-n5649-k365, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5649-k365.png ---
# <div id='7dfa3f25-1f5a-4d32-9cc3-a12fac943d91'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5774-k885 ---
# AILSII_continue_1: 303 entries | best fitness: 672424.0
# AILS2_EoH_Acc_large_continue.jar: 327 entries | best fitness: 672420.0
# AILS2_EoH_Omega2_continue.jar: 210 entries | best fitness: 672586.0
# --- 绘图完成: XLTEST-n5774-k885, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5774-k885.png ---
# <div id='158ec681-a25e-4642-b790-881dfb9a3a4d'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5902-k126 ---
# AILSII_continue_1: 71 entries | best fitness: 131231.0
# AILS2_EoH_Acc_large_continue.jar: 41 entries | best fitness: 131265.0
# AILS2_EoH_Omega2_continue.jar: 38 entries | best fitness: 131264.0
# --- 绘图完成: XLTEST-n5902-k126, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n5902-k126.png ---
# <div id='0f83af42-9497-4db7-b90e-9722ce8ec78f'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6034-k1234 ---
# AILSII_continue_1: 195 entries | best fitness: 990913.0
# AILS2_EoH_Acc_large_continue.jar: 43 entries | best fitness: 991035.0
# AILS2_EoH_Omega2_continue.jar: 159 entries | best fitness: 990986.0
# --- 绘图完成: XLTEST-n6034-k1234, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6034-k1234.png ---
# <div id='9674fc05-408b-4613-b01a-80d9c263e362'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6168-k554 ---
# AILSII_continue_1: 506 entries | best fitness: 1229587.0
# AILS2_EoH_Acc_large_continue.jar: 459 entries | best fitness: 1229749.0
# AILS2_EoH_Omega2_continue.jar: 545 entries | best fitness: 1229611.0
# --- 绘图完成: XLTEST-n6168-k554, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6168-k554.png ---
# <div id='e0e12697-b7c5-4da9-b594-70d2c12dea2e'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6305-k58 ---
# AILSII_continue_1: 85 entries | best fitness: 122975.0
# AILS2_EoH_Acc_large_continue.jar: 57 entries | best fitness: 122997.0
# AILS2_EoH_Omega2_continue.jar: 67 entries | best fitness: 122998.0
# --- 绘图完成: XLTEST-n6305-k58, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6305-k58.png ---
# <div id='472d62a1-5d44-453a-9376-65b719f473bd'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6445-k189 ---
# AILSII_continue_1: 48 entries | best fitness: 83957.0
# AILS2_EoH_Acc_large_continue.jar: 51 entries | best fitness: 83959.0
# AILS2_EoH_Omega2_continue.jar: 56 entries | best fitness: 83954.0
# --- 绘图完成: XLTEST-n6445-k189, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6445-k189.png ---
# <div id='fb795ce8-76e9-4b27-8237-ac17af398378'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6588-k267 ---
# AILSII_continue_1: 54 entries | best fitness: 320109.0
# AILS2_EoH_Acc_large_continue.jar: 48 entries | best fitness: 320122.0
# AILS2_EoH_Omega2_continue.jar: 60 entries | best fitness: 320112.0
# --- 绘图完成: XLTEST-n6588-k267, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6588-k267.png ---
# <div id='5034bc1a-b06e-4ca2-b2a1-d00323c932ad'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6734-k1123 ---
# AILSII_continue_1: 16 entries | best fitness: 895169.0
# AILS2_EoH_Acc_large_continue.jar: 18 entries | best fitness: 895167.0
# AILS2_EoH_Omega2_continue.jar: 16 entries | best fitness: 895167.0
# --- 绘图完成: XLTEST-n6734-k1123, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6734-k1123.png ---
# <div id='148af94b-6f22-42a0-8951-35574a8cac74'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6884-k434 ---
# AILSII_continue_1: 219 entries | best fitness: 491649.0
# AILS2_EoH_Acc_large_continue.jar: 189 entries | best fitness: 491706.0
# AILS2_EoH_Omega2_continue.jar: 168 entries | best fitness: 491715.0
# --- 绘图完成: XLTEST-n6884-k434, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n6884-k434.png ---
# <div id='75e1015d-7846-43ba-b915-6e70d32e3c03'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7037-k2302 ---
# AILSII_continue_1: 607 entries | best fitness: 3427706.0
# AILS2_EoH_Acc_large_continue.jar: 410 entries | best fitness: 3428441.0
# 警告: 文件 ../remote_results/test-continue-XLTEST/AILS2_EoH_Omega2_continue.jar/XLTEST-n7037-k2302_1.csv 为空, 跳过。
# --- 绘图完成: XLTEST-n7037-k2302, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7037-k2302.png ---
# <div id='66a2805c-ab07-4e97-b7f5-6368491169f9'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7193-k157 ---
# AILSII_continue_1: 75 entries | best fitness: 170792.0
# AILS2_EoH_Acc_large_continue.jar: 58 entries | best fitness: 170812.0
# AILS2_EoH_Omega2_continue.jar: 56 entries | best fitness: 170803.0
# --- 绘图完成: XLTEST-n7193-k157, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7193-k157.png ---
# <div id='1cfd1420-904f-4e2b-8fa6-7f9c5277223e'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7353-k77 ---
# AILSII_continue_1: 58 entries | best fitness: 79532.0
# AILS2_EoH_Acc_large_continue.jar: 41 entries | best fitness: 79551.0
# AILS2_EoH_Omega2_continue.jar: 49 entries | best fitness: 79543.0
# --- 绘图完成: XLTEST-n7353-k77, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7353-k77.png ---
# <div id='50256261-64f8-46fa-9e8d-c8e58e9e0f75'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7516-k1223 ---
# AILSII_continue_1: 785 entries | best fitness: 1909828.0
# AILS2_EoH_Acc_large_continue.jar: 506 entries | best fitness: 1910214.0
# AILS2_EoH_Omega2_continue.jar: 762 entries | best fitness: 1909956.0
# --- 绘图完成: XLTEST-n7516-k1223, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7516-k1223.png ---
# <div id='adab13b0-7660-4ae0-86ed-5202269394c3'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7683-k1624 ---
# AILSII_continue_1: 389 entries | best fitness: 1680559.0
# AILS2_EoH_Acc_large_continue.jar: 355 entries | best fitness: 1680624.0
# AILS2_EoH_Omega2_continue.jar: 338 entries | best fitness: 1680729.0
# --- 绘图完成: XLTEST-n7683-k1624, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7683-k1624.png ---
# <div id='fac3b350-ce1f-4524-8dbb-338499599947'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n7854-k395 ---
# AILSII_continue_1: 358 entries | best fitness: 633783.0
# AILS2_EoH_Acc_large_continue.jar: 270 entries | best fitness: 633927.0
# AILS2_EoH_Omega2_continue.jar: 338 entries | best fitness: 633803.0
# --- 绘图完成: XLTEST-n7854-k395, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n7854-k395.png ---
# <div id='981ed44e-8a67-43bd-b0a6-f32ae2e81ce1'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8028-k986 ---
# AILSII_continue_1: 517 entries | best fitness: 806699.0
# AILS2_EoH_Acc_large_continue.jar: 313 entries | best fitness: 806826.0
# AILS2_EoH_Omega2_continue.jar: 482 entries | best fitness: 806788.0
# --- 绘图完成: XLTEST-n8028-k986, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8028-k986.png ---
# <div id='3ff16b2b-0c8e-41fa-a5c9-9d52d2142286'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8207-k649 ---
# AILSII_continue_1: 230 entries | best fitness: 845701.0
# AILS2_EoH_Acc_large_continue.jar: 192 entries | best fitness: 845686.0
# AILS2_EoH_Omega2_continue.jar: 233 entries | best fitness: 845663.0
# --- 绘图完成: XLTEST-n8207-k649, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8207-k649.png ---
# <div id='1e952a2a-7c85-4178-8f14-629a397bab28'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8389-k1106 ---
# AILSII_continue_1: 1241 entries | best fitness: 1737078.0
# AILS2_EoH_Acc_large_continue.jar: 766 entries | best fitness: 1737868.0
# AILS2_EoH_Omega2_continue.jar: 1084 entries | best fitness: 1737486.0
# --- 绘图完成: XLTEST-n8389-k1106, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8389-k1106.png ---
# <div id='e48a2c9d-09e3-4a42-8c50-845be373a587'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8575-k343 ---
# AILSII_continue_1: 135 entries | best fitness: 231345.0
# AILS2_EoH_Acc_large_continue.jar: 82 entries | best fitness: 231381.0
# AILS2_EoH_Omega2_continue.jar: 97 entries | best fitness: 231379.0
# --- 绘图完成: XLTEST-n8575-k343, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8575-k343.png ---
# <div id='b9f1b175-e285-41f4-994b-ed613f0d40eb'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8766-k154 ---
# AILSII_continue_1: 126 entries | best fitness: 251507.0
# AILS2_EoH_Acc_large_continue.jar: 112 entries | best fitness: 251515.0
# AILS2_EoH_Omega2_continue.jar: 100 entries | best fitness: 251533.0
# --- 绘图完成: XLTEST-n8766-k154, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8766-k154.png ---
# <div id='fd58dbe4-fa83-4f04-bad9-3a1f3dac7c64'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n8960-k2144 ---
# AILSII_continue_1: 515 entries | best fitness: 1968886.0
# AILS2_EoH_Acc_large_continue.jar: 379 entries | best fitness: 1969089.0
# AILS2_EoH_Omega2_continue.jar: 68 entries | best fitness: 1969606.0
# --- 绘图完成: XLTEST-n8960-k2144, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n8960-k2144.png ---
# <div id='f1519863-b200-42b7-a93f-256cede17dec'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n9160-k364 ---
# AILSII_continue_1: 202 entries | best fitness: 454840.0
# AILS2_EoH_Acc_large_continue.jar: 128 entries | best fitness: 454902.0
# AILS2_EoH_Omega2_continue.jar: 149 entries | best fitness: 454887.0
# --- 绘图完成: XLTEST-n9160-k364, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n9160-k364.png ---
# <div id='84365910-0eda-4346-a16a-116f9dcf65b2'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n9363-k744 ---
# AILSII_continue_1: 328 entries | best fitness: 871970.0
# AILS2_EoH_Acc_large_continue.jar: 326 entries | best fitness: 872029.0
# AILS2_EoH_Omega2_continue.jar: 321 entries | best fitness: 872006.0
# --- 绘图完成: XLTEST-n9363-k744, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n9363-k744.png ---
# <div id='1aee1ba3-6128-4db6-9f8d-8e28fb194aa6'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n9571-k980 ---
# AILSII_continue_1: 909 entries | best fitness: 1359894.0
# AILS2_EoH_Acc_large_continue.jar: 609 entries | best fitness: 1360091.0
# AILS2_EoH_Omega2_continue.jar: 737 entries | best fitness: 1360116.0
# --- 绘图完成: XLTEST-n9571-k980, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n9571-k980.png ---
# <div id='6ed1fcc1-a56d-445d-883f-7fe35034582e'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n9784-k890 ---
# AILSII_continue_1: 74 entries | best fitness: 724128.0
# AILS2_EoH_Acc_large_continue.jar: 57 entries | best fitness: 724133.0
# AILS2_EoH_Omega2_continue.jar: 63 entries | best fitness: 724141.0
# --- 绘图完成: XLTEST-n9784-k890, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n9784-k890.png ---
# <div id='9148a87b-0cb7-4b27-a9b2-7d94af9136df'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n10001-k806 ---
# AILSII_continue_1: 41 entries | best fitness: 656885.0
# 信息: 文件 None 未找到, 跳过。
# 信息: 文件 None 未找到, 跳过。
# --- 绘图完成: XLTEST-n10001-k806, 图像已保存至 ../figures/continue-XLTEST/plot_best_fitness_XLTEST-n10001-k806.png ---

# %%
from plot_utils import plot_gap_scatter_with_time_limit

plot_gap_scatter_with_time_limit(cur_instance_names, algorithm_names, base_dir=result_dir, output_dir=plot_dir, point_alpha=0.5, point_size=20, time_limit=86400)
# Out:
# --- 开始绘制 Gap 分析 (Time Limit: 86400s) ---
# <div id='757e8e4e-2609-4df0-8841-e4e6e9fecf6d'></div>
# --- Gap 分析完成. 图像已保存至 ../figures/continue-XLTEST/gap_analysis_scatter_limit_86400.png ---

# %%
# instance_dir = '../XLTEST'
# instance_names = [i.split('.')[0] for i in os.listdir(instance_dir)]
plot_gap_scatter_from_sol(cur_instance_names, algorithm_names, base_dir=result_dir, output_dir=plot_dir, point_alpha=0.5, point_size=20)
# Out:
# --- 开始绘制 Gap 分析 (基于 .sol 文件) ---
# <div id='8d8cd010-d4a9-4070-9ab2-ec508754791d'></div>
# --- Gap 分析完成. 图像已保存至 ../figures/continue-XLTEST/gap_analysis_scatter_sol.png ---

# %%
from plot_utils import get_average_gap_statistics

df_avg_gap = get_average_gap_statistics(cur_instance_names, algorithm_names, base_dir=result_dir, baseline='Mahdi_baseline')
df_avg_gap
# Out:
# --- 开始计算平均 Gap (基于 .sol 文件) | Baseline模式: Mahdi_baseline ---
# 未找到有效数据或无法建立基准。
# Empty DataFrame
# Columns: []
# Index: []

# %%
from plot_utils import get_rank_statistics

get_rank_statistics(cur_instance_names, algorithm_names, base_dir=result_dir)
# Out:
# --- 开始统计算法排名情况 (区分 Strict/Tied Rank 1) ---
#
# --- 排名统计表 (Rank Statistics) ---
# Rank_Label                        Strict Rank 1  Tied Rank 1  Rank 2  Rank 3
# Method
# AILS2_EoH_Acc_large_continue.jar              4            1      15      29
# AILS2_EoH_Omega2_continue.jar                10            1      24      14
# AILSII_continue_1                            35            0      10       5
# Rank_Label                        Strict Rank 1  Tied Rank 1  Rank 2  Rank 3
# Method
# AILS2_EoH_Acc_large_continue.jar              4            1      15      29
# AILS2_EoH_Omega2_continue.jar                10            1      24      14
# AILSII_continue_1                            35            0      10       5

# %%
import os
import glob
import pandas as pd
from collections import deque

def get_max_time_from_csv(file_path):
    """
    读取CSV文件的最后一行以提取最大时间。
    如果文件为空，返回 0。
    """
    # 1. 检查文件是否为空
    if os.path.getsize(file_path) == 0:
        return 0.0

    try:
        # 2. 打开文件并只读取最后一行 (使用 deque 只保留最后1行)
        with open(file_path, 'r', encoding='utf-8') as f:
            # deque(f, 1) 会高效地只抓取最后一行
            last_line_gen = deque(f, maxlen=1)
            
            if not last_line_gen: # 双重检查：如果文件有大小但内容为空（如只有换行符）
                return 0.0
            
            last_line = last_line_gen[0].strip()
            
            # 3. 解析数据: {time};{fitness}
            # 假设格式总是分号分隔，且第一列是时间
            if not last_line:
                return 0.0
                
            time_str = last_line.split(';')[0]
            return float(time_str)
            
    except Exception as e:
        print(f"处理文件 {os.path.basename(file_path)} 时出错: {e}")
        return 0.0 # 出错时默认返回0，或者根据需求改为 None

# %%
# ================= 配置路径 =================
# ===========================================

def analysis_max_times(target_path):
    method_name = os.path.basename(target_path)
    
    # 获取所有csv文件
    csv_files = glob.glob(os.path.join(target_path, "*.csv"))
    data_list = []
    
    print(f"正在处理 {len(csv_files)} 个文件...")
    
    for file in csv_files:
        max_time = get_max_time_from_csv(file)
        # 记录文件名（不含路径）和最大时间
        data_list.append({
            'filename': os.path.basename(file),
            'max_time': max_time
        })
    
    # 1. 生成 DataFrame
    df = pd.DataFrame(data_list)
    
    # 按文件名排序（可选，方便查看）
    df = df.sort_values(by='filename').reset_index(drop=True)
    
    print("--- 结果预览 (前5行) ---")
    print(df.head())
    
    print(f"\n--- 统计信息 - {method_name} ---")
    # 2. 做个统计 (均值、最大值、最小值、分位数等)
    stats = df['max_time'].describe()
    print(stats)
    
    zero_count = (df['max_time'] == 0).sum()
    print(f"\n完全无提升instance个数: {zero_count} / {len(df)}")

# 如果你想查看具体的时间分布情况
# print(df['max_time'].value_counts(bins=10))

# %%
target_path = f'{result_dir}/AILS_continue_Mahdi'  # 请修改为你的实际文件夹路径
analysis_max_times(target_path)
# Out:
# 正在处理 0 个文件...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9601/3635544608.py in ?()
#       1 target_path = f'{result_dir}/AILS_continue_Mahdi'  # 请修改为你的实际文件夹路径
# ----> 2 analysis_max_times(target_path)
#
# /tmp/ipykernel_9601/129676124.py in ?(target_path)
#      21     # 1. 生成 DataFrame
#      22     df = pd.DataFrame(data_list)
#      23
#      24     # 按文件名排序（可选，方便查看）
# ---> 25     df = df.sort_values(by='filename').reset_index(drop=True)
#      26
#      27     print("--- 结果预览 (前5行) ---")
#      28     print(df.head())
#
# ~/miniconda3/envs/wsl-cpu/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# ~/miniconda3/envs/wsl-cpu/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'filename'
