# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from plot_utils import plot_search_curves, plot_best_fitness, plot_gap_scatter, plot_gap_scatter_from_sol
# %matplotlib notebook

algorithm_names = [
    'AILSII_origin',
    'AILSII_parallel_v2'
]

# %%
instance_dir = '../XLDemo'
instance_names = [i.split('.')[0] for i in os.listdir(instance_dir)]
plot_gap_scatter(instance_names, algorithm_names, base_dir='../local_results', output_dir='../figures/parallel_results')
# Out:
# --- Starting Gap Analysis ---
# <div id='7b0d0d31-5316-426a-80af-778df65a6c85'></div>
# --- Gap analysis complete. Plot saved to ../figures/parallel_results/gap_analysis_scatter.png ---

# %%
for instance in instance_names:
    plot_best_fitness(instance, algorithm_names, base_dir='../local_results', output_dir='../figures/parallel_results')
# Out:
# <div id='f94148e2-c5cd-4563-8b13-7bdf721ab884'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n5174-k170 ---
# AILSII_origin: 1244 entries | best fitness: 306328.0
# AILSII_parallel_v2: 1163 entries | best fitness: 306552.0
# --- 绘图完成: XLTEST-n5174-k170, 图像已保存至 ../figures/parallel_results/plot_best_fitness_XLTEST-n5174-k170.png ---
# <div id='a12f9906-5cc3-489f-846d-0afbcdf0628b'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n4245-k164 ---
# AILSII_origin: 854 entries | best fitness: 192413.0
# AILSII_parallel_v2: 835 entries | best fitness: 192534.0
# --- 绘图完成: XLTEST-n4245-k164, 图像已保存至 ../figures/parallel_results/plot_best_fitness_XLTEST-n4245-k164.png ---
# <div id='8f918f01-4da9-4793-9e0a-e163bb0dd9b6'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6034-k1234 ---
# AILSII_origin: 1974 entries | best fitness: 991662.0
# AILSII_parallel_v2: 934 entries | best fitness: 995725.0
# --- 绘图完成: XLTEST-n6034-k1234, 图像已保存至 ../figures/parallel_results/plot_best_fitness_XLTEST-n6034-k1234.png ---
# ...

# %%
from plot_utils import get_rank_statistics

algorithm_names = [
    'baseline',
    'AILSII_origin_cpu',
    'AILSII_origin_wall'
]

instance_dir = '../XLTEST'
instance_names = [i.split('.')[0] for i in os.listdir(instance_dir)]
plot_gap_scatter_from_sol(instance_names, algorithm_names, base_dir='../remote_results/test-1day', output_dir='../figures/1day_results', point_alpha=0.5, point_size=20)
# Out:
# --- 开始绘制 Gap 分析 (基于 .sol 文件) ---
# 警告: 无法从实例名 genXLTEST 中提取客户数量，跳过此实例。
# 警告: 无法从实例名 generatorLarge 中提取客户数量，跳过此实例。
# <div id='12f97259-a628-4f98-8d4a-2a57b299b136'></div>
# --- Gap 分析完成. 图像已保存至 ../figures/1day_results/gap_analysis_scatter_sol.png ---

# %%
get_rank_statistics(instance_names, algorithm_names, base_dir='../remote_results/test-1day', output_csv='../figures/1day_results/rank_statistics.csv')
# Out:
# --- 开始统计算法排名情况 (基于 .sol 文件) ---
#
# --- 排名统计表 (Rank Statistics) ---
#                     Rank 1  Rank 2  Rank 3
# Method
# AILSII_origin_cpu       21      38      41
# AILSII_origin_wall      29      35      36
# baseline                54      27      19
# 表格已保存至: ../figures/1day_results/rank_statistics.csv
#                     Rank 1  Rank 2  Rank 3
# Method
# AILSII_origin_cpu       21      38      41
# AILSII_origin_wall      29      35      36
# baseline                54      27      19

# %%
for instance in instance_names:
    plot_best_fitness(instance, algorithm_names, base_dir='../remote_results/test-1day', output_dir='../figures/1day_results')
# Out:
# <div id='47ddca53-5fbf-4060-8fc0-a828862251fb'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3561-k54 ---
# 信息: 文件 None 未找到, 跳过。
# AILSII_origin_cpu: 680 entries | best fitness: 63611.0
# AILSII_origin_wall: 633 entries | best fitness: 63500.0
# --- 绘图完成: XLTEST-n3561-k54, 图像已保存至 ../figures/1day_results/plot_best_fitness_XLTEST-n3561-k54.png ---
# <div id='b5c4c444-e762-4d59-ae49-c5204425c69d'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n6884-k434 ---
# 信息: 文件 None 未找到, 跳过。
# AILSII_origin_cpu: 1953 entries | best fitness: 491785.0
# AILSII_origin_wall: 1897 entries | best fitness: 491629.0
# --- 绘图完成: XLTEST-n6884-k434, 图像已保存至 ../figures/1day_results/plot_best_fitness_XLTEST-n6884-k434.png ---
# <div id='ae807b57-1e6b-4587-8f87-0edf78b35fab'></div>
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n2261-k168 ---
# 信息: 文件 None 未找到, 跳过。
# AILSII_origin_cpu: 605 entries | best fitness: 281413.0
# AILSII_origin_wall: 657 entries | best fitness: 281350.0
# ...
