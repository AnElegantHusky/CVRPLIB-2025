# %%
import os

# %%
algorithm_names = [
    'filo',
    'ails',
    'ails-parallel',
    'ails-perturbance0',
    'ails-perturbance1',
]

instance_names = [i.split('.')[0] for i in os.listdir('../XLTEST')]

# %%
from plot_utils import plot_best_fitness

# %%
import pandas as pd
file_path = 'D:\\CVRPLIB-2025\\local_results\\ails-parallel\\XLTEST-n1048-k139.vrp.csv'
data = pd.read_csv(
                file_path,
                sep='[;,]',
                header=None,
                names=['time', 'fitness'],
                engine='python',
                on_bad_lines='skip'
            )

# %%
plot_best_fitness(instance_names[0], algorithm_names, base_dir='../local_results', output_dir='../figures/ails+parallel')
# Out:
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n1048-k139 ---
# filo: 344 entries | best fitness: 124581
# ails: 265 entries | best fitness: 124134.0
# ails-parallel: 103 entries | best fitness: 125111.0
# ails-perturbance0: 196 entries | best fitness: 124221.0
# ails-perturbance1: 200 entries | best fitness: 124215.0
# --- 绘图完成: XLTEST-n1048-k139, 图像已保存至 ../figures/ails+parallel\plot_best_fitness_XLTEST-n1048-k139.png ---

# %%
for instance in instance_names:
    plot_best_fitness(instance, algorithm_names, base_dir='../local_results', output_dir='../figures/ails+parallel')
# Out:
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n1048-k139 ---
# filo: 344 entries | best fitness: 124581
# ails: 265 entries | best fitness: 124134.0
# ails-parallel: 103 entries | best fitness: 125111.0
# ails-perturbance0: 196 entries | best fitness: 124221.0
# ails-perturbance1: 200 entries | best fitness: 124215.0
# --- 绘图完成: XLTEST-n1048-k139, 图像已保存至 ../figures/ails+parallel\plot_best_fitness_XLTEST-n1048-k139.png ---
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n2168-k625 ---
# filo: 1363 entries | best fitness: 535929
# ails: 592 entries | best fitness: 529907.0
# ails-parallel: 168 entries | best fitness: 533192.0
# ails-perturbance0: 611 entries | best fitness: 530048.0
# ails-perturbance1: 618 entries | best fitness: 530027.0
# --- 绘图完成: XLTEST-n2168-k625, 图像已保存至 ../figures/ails+parallel\plot_best_fitness_XLTEST-n2168-k625.png ---
# --- 开始绘制【最佳Fitness】曲线: XLTEST-n3101-k685 ---
# filo: 1756 entries | best fitness: 565704
# ails: 749 entries | best fitness: 563123.0
# ...
